# %%
from delayfunctions import *

# %% [markdown]
# # Small dataset to test code (~100 traces, 1200 Max Measurements)

# %%
path = 'sensL sipm delays 20 cm/SNSL_sipm_trace_20_f'
numshots = len([entry for entry in os.listdir(path) if os.path.isfile(os.path.join(path, entry))])

td_trace = get_timing_delays_trace(path, numshots, 3, 0.3)

data = pd.read_csv('sensL sipm delays 20 cm/SNSL_sipm_delay_20_f.csv')
meas = get_timing_delays_leadingedge(data, 1500, 3000)
# Out:
# Mean: -14.869 ns
# Standard Deviation: 0.423 ns
# Median: -14.922 ns
# Mean: -15.303 ns
# Standard Deviation: 1.071 ns
# Median: -15.310 ns

# %%
delay_distances = [20, 40, 60, 80, 100, 120, 150]
frac = 0.7
td_trace_all = []
td_meas_all = []

# %% [markdown]
# # Larger datasets (800 traces (before filtering), 1200 Max Measurements)
#
# ## 20 cm

# %%
path = 'sensL sipm delays 20 cm/SNSL_sipm_trace_20_3'

td_trace = get_timing_delays_trace(path, 20, frac)

data = pd.read_csv('sensL sipm delays 20 cm/SNSL_sipm_delay_20_2.csv')
td_meas = get_timing_delays_leadingedge(data, 1200, 3000)

td_trace_all.append(td_trace)
td_meas_all.append(td_meas)

overlay_plots(td_trace, td_meas)
# Out:
# Mean: -14.982 ns
# Standard Deviation: 0.377 ns
# Median: -14.953 ns
# Mean: -15.186 ns
# Standard Deviation: 1.162 ns
# Median: -15.210 ns

# %% [markdown]
# ## 40 cm

# %%
path = 'sensL sipm delays 40 cm/SNSL_sipm_trace_40_3'
td_trace = get_timing_delays_trace(path, 20, frac)

data = pd.read_csv('sensL sipm delays 40 cm/SNSL_sipm_delay_40_3.csv')
td_meas = get_timing_delays_leadingedge(data, 1200, 3000)

td_trace_all.append(td_trace)
td_meas_all.append(td_meas)

overlay_plots(td_trace, td_meas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-6cce5459e41b> in <module>
#       1 path = 'sensL sipm delays 40 cm/SNSL_sipm_trace_40_3'
# ----> 2 td_trace = get_timing_delays_trace(path, 20, frac)
#       3
#       4 data = pd.read_csv('sensL sipm delays 40 cm/SNSL_sipm_delay_40_3.csv')
#       5 td_meas = get_timing_delays_leadingedge(data, 1200, 3000)
#
# TypeError: get_timing_delays_trace() missing 1 required positional argument: 'fraction'

# %% [markdown]
# # 60 cm

# %%
path = 'sensL sipm delays 60 cm/SNSL_sipm_trace_60_3'
td_trace = get_timing_delays_trace(path, 20, frac)

data = pd.read_csv('sensL sipm delays 60 cm/SNSL_sipm_delay_60_3.csv')
td_meas = get_timing_delays_leadingedge(data, 1200, 3000)

td_trace_all.append(td_trace)
td_meas_all.append(td_meas)

overlay_plots(td_trace, td_meas)
# Out:
# Mean: -10.326 ns
# Standard Deviation: 0.364 ns
# Median: -10.312 ns
# Mean: -10.369 ns
# Standard Deviation: 1.198 ns
# Median: -10.390 ns

# %% [markdown]
# # 80 cm

# %%
path = 'sensL sipm delays 80 cm/SNSL_sipm_trace_80_3'
td_trace = get_timing_delays_trace(path, 20, frac)

data = pd.read_csv('sensL sipm delays 80 cm/SNSL_sipm_delay_80_3.csv')
td_meas = get_timing_delays_leadingedge(data, 1200, 3000)

td_trace_all.append(td_trace)
td_meas_all.append(td_meas)

overlay_plots(td_trace, td_meas)
# Out:
# Mean: -8.193 ns
# Standard Deviation: 0.422 ns
# Median: -8.125 ns
# Mean: -8.207 ns
# Standard Deviation: 1.221 ns
# Median: -8.200 ns

# %% [markdown]
# # 100 cm

# %%
path = 'sensL sipm delays 100 cm/SNSL_sipm_trace_100_3'
td_trace = get_timing_delays_trace(path,20, frac)

data = pd.read_csv('sensL sipm delays 100 cm/SNSL_sipm_delay_100_3.csv')
td_meas = get_timing_delays_leadingedge(data, 1200, 3000)

td_trace_all.append(td_trace)
td_meas_all.append(td_meas)

overlay_plots(td_trace, td_meas)
# Out:
# Mean: -6.094 ns
# Standard Deviation: 0.395 ns
# Median: -6.094 ns
# Mean: -6.073 ns
# Standard Deviation: 1.197 ns
# Median: -6.020 ns

# %% [markdown]
# # 120 cm

# %%
path = 'sensL sipm delays 120 cm/SNSL_sipm_trace_120_3'
td_trace = get_timing_delays_trace(path, 20, frac)

data = pd.read_csv('sensL sipm delays 120 cm/SNSL_sipm_delay_120_3.csv')
td_meas = get_timing_delays_leadingedge(data, 1200, 3000)

td_trace_all.append(td_trace)
td_meas_all.append(td_meas)

overlay_plots(td_trace, td_meas)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-b8c60eaa585b> in <module>
#       1 path = 'sensL sipm delays 120 cm/SNSL_sipm_trace_120_3'
# ----> 2 td_trace = get_timing_delays_trace(path, 20, frac)
#       3
#       4 data = pd.read_csv('sensL sipm delays 120 cm/SNSL_sipm_delay_120_3.csv')
#       5 td_meas = get_timing_delays_leadingedge(data, 1200, 3000)
#
# ~/MATHUSLA/delayfunctions.py in get_timing_delays_trace(path, sigma, fraction, plot)
#      46 def get_timing_delays_trace(path, sigma, fraction, plot=True):
#      47
# ---> 48     num_traces = len([entry for entry in os.listdir(path) if os.path.isfile(os.path.join(path, entry))])
#      49     time_delays = []
#      50     csv_files = glob.glob(os.path.join(path, "*.csv"))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sensL sipm delays 120 cm/SNSL_sipm_trace_120_3'

# %%
#plt.scatter(delay_distances,)
stds_tr = []
stds_meas = []
for i in range(len(td_trace_all)):
    stds_tr.append(np.std(td_trace_all[i]))
    stds_meas.append(np.std(td_meas_all[i]))

# %%
plt.scatter(delay_distances[:len(stds_tr)], stds_tr, label = "Constant Frac. (70%)")
plt.scatter(delay_distances[:len(stds_tr)], stds_meas, color='orange', label = "Leading Edge (Max Meas.)")

plt.ylim(0, max(stds_meas) + 0.5 * max(stds_meas))

plt.xticks(fontsize=14)
plt.xlabel("Disctance from laser to SiPM 1 (cm)")
plt.yticks(fontsize=14)
plt.ylabel("Standard Deviation of Time Delay Histogram (s)")
plt.title("Comparing two different timing methods", fontsize=14)
plt.legend(frameon=True, fancybox=True, facecolor='snow', fontsize=13)
plt.show()

# %%
stds_meas

# %%
stds_tr

# %%
np.array([1,2,3]) + 1

# %%
np.array([1,2,3]) + np.array([1,1,2])

# %%
from delayfunctions import *

data = pd.read_csv('sensL sipm delays 20 cm/SNSL_sipm_trace_20_f/Capture #11.csv', skiprows=1)

signal1 = scipy.ndimage.gaussian_filter(np.array(data['1 (VOLT)']), 20)
signal2 = scipy.ndimage.gaussian_filter(np.array(data['4 (VOLT)']), 20)

time = np.array(data['Time (s)'])

time1, cdf1 = cdf(signal1, time, 0.5)
time2, cdf2 = cdf(signal2, time, 0.5)

# %%
time_delay_cdf(cdf1, cdf2, time1, time2)

# %%
#plt.plot(signal, color='black', label= 'original signal')
#plt.plot(atten, color='red', label='attenuated signal')
#plt.plot(inverted, color='orange', label='inverted signal')
#plt.plot(shifted, color='blue', label='shifted signal')
plt.plot(time1, cdf1, color='green', label= '1')
plt.plot(time2, cdf2, color='purple', label= '4')
plt.axhline(0, color='black')

plt.show()
plt.plot(time, signal1)
plt.plot(time, signal2)
plt.plot()

#plt.plot(signal, color='black')
#plt.plot(cdf, color='orange')
#plt.legend()
#plt.plot()

# %%
from delayfunctions import *
time_delays = []
path = 'sensL sipm delays 40 cm/SNSL_sipm_trace_40_3'
csv_files = glob.glob(os.path.join(path, "*.csv"))
for f in csv_files:
    


    #print("Capture: #", counter)
    # read the csv file
    data = pd.read_csv(f, skiprows=1)
    
    p1 = scipy.ndimage.gaussian_filter(np.array(data['1 (VOLT)']), 30)
    p2 = scipy.ndimage.gaussian_filter(np.array(data['4 (VOLT)']), 30)

    
    if(all(i < 0.001 for i in p1) or all(i < 0.001 for i in p2)):
        continue
    time = np.array(data['Time (s)'])
    
    time1, cdf1 = cdf(p1, time, 0.8)
    time2, cdf2 = cdf(p2, time, 0.8)
    
    
    t1, t2, td = time_delay_cdf(cdf1, cdf2, time1, time2)


    '''plt.plot(time1, cdf1, color='green', label= '1')
    plt.plot(time2, cdf2, color='purple', label= '4')
    plt.axhline(0, color='black')
    plt.axvline(t1, color='green')
    plt.axvline(t2, color='purple')
    plt.show()'''


    
    time_delays.append(td)

# %%
plt.hist(np.array(time_delays), density=True, alpha=0.6, color='purple', bins=10)
mu, std = norm.fit(time_delays)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
plt.show()

# %%
mean_rounded = "{:.3f}".format((np.mean(time_delays)) * 10 ** 9)
sr_rounded = "{:.3f}".format((np.std(time_delays)) * 10 ** 9)
median_rounded = "{:.3f}".format((np.median(time_delays)) * 10 ** 9)

mean = "Mean: " + str(mean_rounded) + " ns"
SD = "Standard Deviation: " + str(sr_rounded) + " ns"
median = "Median: " + str(median_rounded) + " ns"

print(mean)
print(SD)
print(median)
