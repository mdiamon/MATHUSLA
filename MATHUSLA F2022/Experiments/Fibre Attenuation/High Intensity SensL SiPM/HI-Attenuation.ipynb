# %% [markdown]
# ## Attenuation successful run
#
# We pivoted to using the fibre spool as used in the capstone project. This allowed us to collect attenuation data with a much more stable coupling efficiency, as we did not have to move the fibre between delay distances; only the pulser was moved.

# %%
import sys        
sys.path.append('/Users/lanabozanic/MATHUSLA') # Change this to the dir where mathusladataprocessing.py is.     

from mathusladataprocessing import *

# %% [markdown]
# # Bias voltage = -0.5V

# %%
distances = [165]
d = 165
for i in range(21):
    d += 53.4
    distances.append(round(d))
distances = np.array(distances) / 1000
distances
# Out:
# array([0.165, 0.218, 0.272, 0.325, 0.379, 0.432, 0.485, 0.539, 0.592,
#        0.646, 0.699, 0.752, 0.806, 0.859, 0.913, 0.966, 1.019, 1.073,
#        1.126, 1.18 , 1.233, 1.286])

# %%
bias05 = Attenuation(distances, "attenuation -- circle fibre holder", channels=['1', '4'], maxx='max')
m05, s05 = test1.histogram(10)
# Out:
# test 2/0 ATT_circle_165mm_-07.csv
# test 2/1 ATT_circle_379mm_-07.csv
# test 2/2 ATT_circle_592mm_-07.csv
# test 2/3 ATT_circle_806mm_-07.csv
# test 2/4 ATT_circle_1020mm_-07.csv
# test 2/5 ATT_circle_1233mm_-07.csv
# test 2/6 ATT_circle_1445mm_-07.csv
# test 2/7 ATT_circle_1660mm_-07.csv
# test 2/8 ATT_circle_1874mm_-07.csv
# test 2/9 ATT_circle_2088mm_-07.csv
# test 2/A ATT_circle_2301mm_-07.csv
# test 2/B ATT_circle_2515mm_-07.csv
# test 2/C ATT_circle_2729mm_-07.csv

# %%
summary_attn(distances, [bias05.amplitudes()], ['1.2mm'], ['orange'])
# Out:
# rmsd:  0.0045647268344960554
# rmsd:  0.003802539641954984
# rmsd:  2.2435320480273115

# %% [markdown]
# # Bias voltage = -0.7V

# %%
distances_07 = [165]
d = 165
for i in range(12):
    d += (53.4 * 4)
    distances_07.append(round(d))
distances_07 = np.array(distances_07) / 1000
distances_07
# Out:
# array([0.165, 0.379, 0.592, 0.806, 1.019, 1.233, 1.447, 1.66 , 1.874,
#        2.087, 2.301, 2.515, 2.728])

# %%
bias07 = Attenuation(distances_07, "test 2", channels=['1', '4'], maxx='max')
m07, s07 = test2.histogram(10)
# Out:
# test 2/0 ATT_circle_165mm_-07.csv
# test 2/1 ATT_circle_379mm_-07.csv
# test 2/2 ATT_circle_592mm_-07.csv
# test 2/3 ATT_circle_806mm_-07.csv
# test 2/4 ATT_circle_1020mm_-07.csv
# test 2/5 ATT_circle_1233mm_-07.csv
# test 2/6 ATT_circle_1445mm_-07.csv
# test 2/7 ATT_circle_1660mm_-07.csv
# test 2/8 ATT_circle_1874mm_-07.csv
# test 2/9 ATT_circle_2088mm_-07.csv
# test 2/A ATT_circle_2301mm_-07.csv
# test 2/B ATT_circle_2515mm_-07.csv
# test 2/C ATT_circle_2729mm_-07.csv

# %%
summary_attn(distances_07, [bias07.amplitudes()], ['1.2'], ['purple'])
# Out:
# rmsd:  0.0027950094657533424
# rmsd:  0.00281209220553163
# rmsd:  1.4021464779464976
