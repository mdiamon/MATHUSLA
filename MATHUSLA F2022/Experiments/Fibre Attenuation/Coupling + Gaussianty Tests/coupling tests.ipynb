# %% [markdown]
# Here we investigate the coupling effiency of the spool that is used in our attenuation measurements.
#
# We are interested in tunderstanding whether or not the coupling is constant when we take out the light source and reinstall it into the same hole in the spool.

# %%
import sys        
sys.path.append('/Users/lanabozanic/MATHUSLA') # Change this to the dir where mathusladataprocessing.py is.     

from mathusladataprocessing import *

# %% [markdown]
# ## Test 1
#
# Here we test the coupling effiency when we take the led pulser in and out of the hole.

# %%
a1 = Attenuation([], "coupling tests", channels=['1', '4'], maxx='min')
coupling_eff(a1.amplitudes())

# %%
a2 = Attenuation([], "gaus+coupling SM connector", channels=['1', '4'], maxx='min')
coupling_eff(a2.amplitudes())

# %%
m1, s1=a1.histogram(bins=20)
# Out:
# coupling tests/attn_coupling_test 0.csv
# coupling tests/attn_coupling_test__2.csv
# coupling tests/attn_coupling_test__3.csv
# coupling tests/attn_coupling_test__4.csv

# %% [markdown]
# ## Test 2
#
# Here we take the cut, polished, taped SMA connector in and out of the hole, for the three holes on a single notch.

# %%
a3 = Attenuation([], "coupling test -- one column/couple 1", channels=['1', '4'], maxx='min')
coupling_eff(a3.amplitudes())

# %%
a4 = Attenuation([], "coupling test -- one column/couple 2", channels=['1', '4'], maxx='min')
coupling_eff(a4.amplitudes())

# %%
a5 = Attenuation([], "coupling test -- one column/couple 3", channels=['1', '4'], maxx='min')
coupling_eff(a5.amplitudes())

# %%
coupling_eff("coupling test -- one column/coupling tests w new spool", 'min')
# Out:
# 0 coupling test -- one column/coupling tests w new spool/coupling_new3d_11.csv
# 1 coupling test -- one column/coupling tests w new spool/coupling_new3d_12.csv
# 2 coupling test -- one column/coupling tests w new spool/coupling_new3d_13.csv
# 3 coupling test -- one column/coupling tests w new spool/coupling_new3d_14.csv

# %% [markdown]
# Coupling is relatively constant for each hole.
