# %%
import sys        
sys.path.append('/Users/lanabozanic/MATHUSLA') # Change this to the dir where mathusladataprocessing.py is.     

from mathusladataprocessing import *

# %%
a1 = Attenuation([], "biased measurements", maxx='min', channels=['4'])
#means, stds=amp_hist("biased measurements", 'min', single_fit=False,ch1_on=False, bins=120)
m1, s1 = a1.histogram(single_fit=False, bins=150)
# Out:
# biased measurements/vbias_-1_50V 0.csv
# biased measurements/vbias_-1_51V.csv
# biased measurements/vbias_-1_52V.csv
# biased measurements/vbias_-1_53V.csv
# biased measurements/vbias_-1_54V.csv
# biased measurements/vbias_-1_55V.csv
# biased measurements/vbias_-1_56V 4.csv
# biased measurements/vbias_-1_6V.csv
