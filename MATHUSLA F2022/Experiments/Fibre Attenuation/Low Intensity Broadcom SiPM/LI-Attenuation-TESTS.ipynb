# %% [markdown]
# bias voltage -0.7V (lowest voltage that gives Ch4 a signal from 3m of fibre away)

# %%
import sys        
sys.path.append('/Users/lanabozanic/MATHUSLA') # Change this to the dir where mathusladataprocessing.py is.     

from mathusladataprocessing import *

# %%
distances = [327]
d= 327
for i in range(14):
    d += 51.05 * 3
    distances.append(round(d))
distances = np.array(distances) / 1000
print(distances)
# Out:
# [0.327 0.48  0.633 0.786 0.94  1.093 1.246 1.399 1.552 1.705 1.859 2.012
#  2.165 2.318 2.471]

# %%
test1 = Attenuation(distances, "test data/1.8mm", channels=['1', '4'], maxx='min')

# %%
amps_18 = test1.amplitudes()

# %%
summary_attn(distances, [amps_18], ["1.8"], ['green'])
# Out:
# rmsd:  0.006960266098957646
# rmsd:  0.008270496557858532
# rmsd:  1.1345015781011636

# %%
test2 = Attenuation(distances, "test data/2.0mm", channels=['1', '4'], maxx='min')
amps_20 = test2.amplitudes()

# %%
summary_attn(distances[:10], [amps_20], ["2.0"], ['red'])
# Out:
# rmsd:  0.0039901374663081895
# rmsd:  0.0014421708183928732
# rmsd:  0.8993697219169132
