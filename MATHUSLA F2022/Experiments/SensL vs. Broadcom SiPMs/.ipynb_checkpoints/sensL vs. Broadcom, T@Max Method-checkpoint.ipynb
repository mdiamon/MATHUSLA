# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math as math
import scipy
from scipy.stats import norm
from scipy.signal import argrelextrema
import os, glob

# %%
def histogramCalc(data, small_length, length, plot=True): 
    
    # Grab the data
    data.columns
    pulse1 = np.array(data['X at Max Y(1)'])
    pulse2 = np.array(data['X at Max Y(4)'])

    
    # delete the largest argument from both datasets
    argument1 = np.where(pulse1 > np.quantile(pulse1, 0.95))
    argument3 = np.where(pulse1 < np.quantile(pulse1,0.05))
    argument2 = np.where(pulse2 > np.quantile(pulse2, 0.95))
    argument4 = np.where(pulse2 < np.quantile(pulse2,0.05))
    
    del_args = np.append(argument1, np.append(argument2, np.append(argument3, argument4)))
    #print(del_args)
    
    pulse1_clean = np.delete(pulse1, del_args)

    pulse2_clean = np.delete(pulse2, del_args)

    # create an array of the difference between the new datasets
    time_delays = []
    for i in range(len(pulse1_clean)):
        time_delays.append(pulse1_clean[i] - pulse2_clean[i])

        
    time_delays = np.array(time_delays)
    
    #del_args = np.where(e > np.quantile(e, 0.999))
    #e = np.delete(e, del_args)
    
    #print(e)
    #print(len(e))

    # Create plot
    if(plot == True):
        plt.xlabel("DELAY. SGB-BCF92. " + str(small_length) + "mm")
        plt.ylabel("Frequency")
        #vx = np.random.gamma(4, 0.5, 1000) idk what this is for
        plt.axvline(time_delays.mean(),color='k', linestyle='dashed', linewidth=1)

        mu, std = norm.fit(time_delays) # find the mean & std of the data fitted to a norm. dist.

        plt.hist(time_delays, density=True, alpha=0.6, color='b')

        xmin, xmax = plt.xlim()
        x = np.linspace(xmin, xmax, 100)
        p = norm.pdf(x, mu, std)

        plt.plot(x, p, 'k', linewidth=2)
        title = "Fit Values: {:.2f} and {:.2f}".format(mu, std)

        plt.show()

        mean_rounded = "{:.3f}".format((np.mean(time_delays)) * 10 ** 9)
        sr_rounded = "{:.3f}".format((np.std(time_delays)) * 10 ** 9)
        median_rounded = "{:.3f}".format((np.median(time_delays)) * 10 ** 9)

        mean = "Mean: " + str(mean_rounded) + " ns"
        SD = "Standard Deviation: " + str(sr_rounded) + " ns"
        median = "Median: " + str(median_rounded) + " ns"

        print(mean)
        print(SD)
        print(median)
    return time_delays
    #return a,b,c,d,e

# %%
def comparison_plot(sensl, broadcom):
    plt.hist(sensl, density=True, alpha=0.6, color='pink', label = 'SensL')

    mu_s, std_s = norm.fit(sensl) 
    xmin_s, xmax_s = plt.xlim()
    x_s = np.linspace(xmin_s, xmax_s, 100)
    p_s = norm.pdf(x_s, mu_s, std_s)
    plt.plot(x_s, p_s, 'k', linewidth=2)

    print("SensL Statistics:\nMean:", np.round(np.mean(sensl) * 10 ** 9, 3), "ns\nStandard Dev.:", np.round(np.std(sensl) * 10 ** 9, 3), "ns\nMedian:", np.round(np.median(sensl) * 10 ** 9, 3), "\n")

    plt.hist(broadcom, density=True, alpha=0.6, color='purple', label = 'Broadcom')

    mu_b, std_b = norm.fit(broadcom) 
    xmin_b, xmax_b = plt.xlim()
    x_b = np.linspace(xmin_b, xmax_b, 100)
    p_b = norm.pdf(x_b, mu_b, std_b)
    plt.plot(x_b, p_b, 'k', linewidth=2)
    print("Broadcom Statistics:\nMean:", np.round(np.mean(broadcom) * 10 ** 9, 3), "ns\nStandard Dev.:", np.round(np.std(broadcom) * 10 ** 9, 3), "ns\nMedian:", np.round(np.median(broadcom) * 10 ** 9, 3), "\n")

    
    plt.title("SensL vs. Broadcom SiPM time delays")

    plt.xlabel('Time (s)')
    plt.ylabel('Frequency')
    
    plt.legend()
    plt.show()
    print("Difference in time delay std: ", abs(np.round((np.std(sensl) - np.std(broadcom)) * 10 ** 9, 3)), "ns")

# %%
# snsl data
sensl = pd.read_csv("sensL SiPM data/305mm_1-2fibre_delay.csv")
broadcom = pd.read_csv("Broadcom SiPM data/XaM_DEL_SGB-BCF-1-2_R1.csv")
sensl_delays = histogramCalc(sensl, 1200, 3000, False)
broadcom_delays = histogramCalc(broadcom, 1200, 3000, False)
comparison_plot(sensl_delays, broadcom_delays)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f62fff3132ab> in <module>
#       4 sensl_delays = histogramCalc(sensl, 1200, 3000, False)
#       5 broadcom_delays = histogramCalc(broadcom, 1200, 3000, False)
# ----> 6 comparison_plot(sensl_delays, broadcom_delays)
#
# <ipython-input-7-cb4fda05473d> in comparison_plot(sensl, broadcom)
#       2     plt.hist(sensl, density=True, alpha=0.6, color='pink', label = 'SensL')
#       3
# ----> 4     mu_s, std_s = norm.fit(sensl)
#       5     xmin_s, xmax_s = plt.xlim()
#       6     x_s = np.linspace(xmin_s, xmax_s, 100)
#
# NameError: name 'norm' is not defined

# %%
# snsl data
sensl = pd.read_csv("sensL SiPM data/613mm_1-2fibre_delay.csv")
broadcom = pd.read_csv("Broadcom SiPM data/XaM_DEL_SGB-BCF-1-2_R2.csv")
sensl_delays = histogramCalc(sensl, 1200, 3000, False)
broadcom_delays = histogramCalc(broadcom, 1200, 3000, False)
comparison_plot(sensl_delays, broadcom_delays)
# Out:
# SensL Statistics:
# Mean: -10.403 ns
# Standard Dev.: 1.307 ns
# Median: -10.4
#
# Broadcom Statistics:
# Mean: -10.234 ns
# Standard Dev.: 0.628 ns
# Median: -10.22
# Difference in time delay std:  0.679 ns

# %%
# snsl data
sensl = pd.read_csv("sensL SiPM data/908mm_1-2fibre_delay.csv")
broadcom = pd.read_csv("Broadcom SiPM data/XaM_DEL_SGB-BCF-1-2_R3.csv")
sensl_delays = histogramCalc(sensl, 1200, 3000, False)
broadcom_delays = histogramCalc(broadcom, 1200, 3000, False)
comparison_plot(sensl_delays, broadcom_delays)
# Out:
# SensL Statistics:
# Mean: -6.991 ns
# Standard Dev.: 1.352 ns
# Median: -7.0
#
# Broadcom Statistics:
# Mean: -7.012 ns
# Standard Dev.: 0.617 ns
# Median: -7.05
# Difference in time delay std:  0.735 ns

# %%
# snsl data
sensl = pd.read_csv("sensL SiPM data/1187mm_1-2fibre_delay.csv")
broadcom = pd.read_csv("Broadcom SiPM data/XaM_DEL_SGB-BCF-1-2_R4.csv")
sensl_delays = histogramCalc(sensl, 1200, 3000, False)
broadcom_delays = histogramCalc(broadcom, 1200, 3000, False)
comparison_plot(sensl_delays, broadcom_delays)
# Out:
# SensL Statistics:
# Mean: -3.634 ns
# Standard Dev.: 1.255 ns
# Median: -3.6
#
# Broadcom Statistics:
# Mean: -3.55 ns
# Standard Dev.: 0.698 ns
# Median: -3.53
# Difference in time delay std:  0.557 ns

# %%
# snsl data
sensl = pd.read_csv("sensL SiPM data/1473mm_1-2fibre_delay.csv")
broadcom = pd.read_csv("Broadcom SiPM data/XaM_DEL_SGB-BCF-1-2_R5.csv")
sensl_delays = histogramCalc(sensl, 1200, 3000, False)
broadcom_delays = histogramCalc(broadcom, 1200, 3000, False)
comparison_plot(sensl_delays, broadcom_delays)
# Out:
# SensL Statistics:
# Mean: -0.246 ns
# Standard Dev.: 1.343 ns
# Median: -0.2
#
# Broadcom Statistics:
# Mean: -0.39 ns
# Standard Dev.: 0.569 ns
# Median: -0.4
# Difference in time delay std:  0.773 ns

# %%
# snsl data
sensl = pd.read_csv("sensL SiPM data/1756mm_1-2fibre_delay.csv")
broadcom = pd.read_csv("Broadcom SiPM data/XaM_DEL_SGB-BCF-1-2_R6.csv")
sensl_delays = histogramCalc(sensl, 1200, 3000, False)
broadcom_delays = histogramCalc(broadcom, 1200, 3000, False)
comparison_plot(sensl_delays, broadcom_delays)
# Out:
# SensL Statistics:
# Mean: 2.946 ns
# Standard Dev.: 1.303 ns
# Median: 2.8
#
# Broadcom Statistics:
# Mean: 2.906 ns
# Standard Dev.: 0.714 ns
# Median: 2.87
# Difference in time delay std:  0.589 ns
