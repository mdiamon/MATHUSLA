# %%
import sys        
sys.path.append('/Users/lanabozanic/MATHUSLA') # Change this to the dir where mathusladataprocessing.py is.     

from mathusladataprocessing import *

# %%
for f in sorted(glob.glob(os.path.join("1.2mm delay ext trigger", "*.csv"))):
    print(f)
    tds = Timing('t@max', channels=['1', '4'], data = f).td_TAM()
# Out:
# 1.2mm delay ext trigger/0 LIR_delay_327mm_1-2_ext.csv
# - Mean: 14.072 ns \\
# - Standard Deviation: 2.093 ns \\
# - Median: 14.400 ns \\
# 1.2mm delay ext trigger/1 LIR_delay_633mm_1-2_ext.csv
# - Mean: 10.274 ns \\
# - Standard Deviation: 2.429 ns \\
# - Median: 10.200 ns \\
# 1.2mm delay ext trigger/2 LIR_delay_940mm_1-2_ext.csv
# - Mean: 6.538 ns \\
# - Standard Deviation: 2.658 ns \\
# - Median: 6.100 ns \\
# 1.2mm delay ext trigger/3 LIR_delay_1246mm_1-2_ext.csv
# - Mean: 2.704 ns \\
# - Standard Deviation: 2.538 ns \\
# - Median: 2.500 ns \\
# 1.2mm delay ext trigger/4 LIR_delay_1552mm_1-2_ext.csv
# - Mean: -1.097 ns \\
# - Standard Deviation: 3.461 ns \\
# - Median: -0.800 ns \\
# 1.2mm delay ext trigger/5 LIR_delay_1859mm_1-2_ext.csv
# - Mean: -4.724 ns \\
# - Standard Deviation: 3.321 ns \\
# - Median: -4.300 ns \\
# 1.2mm delay ext trigger/6 LIR_delay_2165mm_1-2_ext.csv
# - Mean: -7.815 ns \\
# - Standard Deviation: 2.700 ns \\
# - Median: -7.200 ns \\
# 1.2mm delay ext trigger/7 LIR_delay_2417mm_1-2_ext.csv
# - Mean: -12.231 ns \\
# - Standard Deviation: 3.922 ns \\
# - Median: -11.500 ns \\

# %%
for f in sorted(glob.glob(os.path.join("1.2mm delay ext trigger", "*.csv"))):
    print(f)
    tds = Timing('t@max', channels=['1', '4'], data = f).single_histograms()
# Out:
# 1.2mm delay ext trigger/0 LIR_delay_327mm_1-2_ext.csv
# Channel 1 stats
# - Mean: 36.333 ns \\
# - Standard Deviation: 1.657 ns \\
# - Median: 36.700 ns \\
#
# Channel 4 stats
# - Mean: 22.261 ns \\
# - Standard Deviation: 1.292 ns \\
# - Median: 22.200 ns \\
# 1.2mm delay ext trigger/1 LIR_delay_633mm_1-2_ext.csv
# Channel 1 stats
# - Mean: 34.537 ns \\
# - Standard Deviation: 1.631 ns \\
# - Median: 33.800 ns \\
#
# Channel 4 stats
# - Mean: 24.263 ns \\
# - Standard Deviation: 1.689 ns \\
# - Median: 24.200 ns \\
# 1.2mm delay ext trigger/2 LIR_delay_940mm_1-2_ext.csv
# Channel 1 stats
# - Mean: 32.903 ns \\
# - Standard Deviation: 1.862 ns \\
# - Median: 33.000 ns \\
#
# Channel 4 stats
# - Mean: 26.365 ns \\
# - Standard Deviation: 1.847 ns \\
# - Median: 26.700 ns \\
# 1.2mm delay ext trigger/3 LIR_delay_1246mm_1-2_ext.csv
# Channel 1 stats
# - Mean: 30.954 ns \\
# - Standard Deviation: 1.772 ns \\
# - Median: 30.000 ns \\
#
# Channel 4 stats
# - Mean: 28.250 ns \\
# - Standard Deviation: 1.861 ns \\
# - Median: 27.700 ns \\
# 1.2mm delay ext trigger/4 LIR_delay_1552mm_1-2_ext.csv
# Channel 1 stats
# - Mean: 29.344 ns \\
# - Standard Deviation: 1.648 ns \\
# - Median: 29.400 ns \\
#
# Channel 4 stats
# - Mean: 30.441 ns \\
# - Standard Deviation: 3.062 ns \\
# - Median: 30.200 ns \\
# 1.2mm delay ext trigger/5 LIR_delay_1859mm_1-2_ext.csv
# Channel 1 stats
# - Mean: 27.310 ns \\
# - Standard Deviation: 1.446 ns \\
# - Median: 27.000 ns \\
#
# Channel 4 stats
# - Mean: 32.034 ns \\
# - Standard Deviation: 3.013 ns \\
# - Median: 31.300 ns \\
# 1.2mm delay ext trigger/6 LIR_delay_2165mm_1-2_ext.csv
# Channel 1 stats
# - Mean: 25.362 ns \\
# - Standard Deviation: 1.222 ns \\
# - Median: 25.200 ns \\
#
# Channel 4 stats
# - Mean: 33.178 ns \\
# - Standard Deviation: 2.398 ns \\
# - Median: 32.200 ns \\
# 1.2mm delay ext trigger/7 LIR_delay_2417mm_1-2_ext.csv
# Channel 1 stats
# - Mean: 23.557 ns \\
# - Standard Deviation: 1.096 ns \\
# - Median: 23.600 ns \\
#
# Channel 4 stats
# - Mean: 35.788 ns \\
# - Standard Deviation: 3.772 ns \\
# - Median: 34.800 ns \\
