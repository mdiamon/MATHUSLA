# %%
import sys        
sys.path.append('/Users/lanabozanic/MATHUSLA/MATHUSLA F2022') # Change this to the dir where mathusladataprocessing.py is.     

from mathusladataprocessing import *

# %% [markdown]
# # Frequency = 25000 Hz (accidentally forgot to change it back to 100 Hz)

# %%
fibres1 = Attenuation([],"1 Hole, Thick/Attenuation 1.2mm Fibre_ 1 fibre", channels=['1', '4'], maxx='min')
fibres2= Attenuation([],"1 Hole, Thick/Attenuation 1.2mm Fibre_ 2 fibres", channels=['1', '4'], maxx='min')

# %%
fibres1.amplitudes()
# Out:
# {'1': [-0.00617903038674032, -0.007737220220220198, -0.007635443258971859],
#  '4': [-0.010218479742173138, -0.010820510510510525, -0.010412317167798267]}

# %%
fibres2.amplitudes()
# Out:
# {'1': [-0.010329487204724427, -0.016257235346358798, -0.016888358653846115],
#  '4': [-0.010344548228346446, -0.011018404973357035, -0.009610624038461532]}

# %%
plt.style.use('seaborn')
plt.scatter([1,2,3],fibres1.amplitudes()['1'], label='1 Fibre')
plt.scatter([1,2,3],fibres2.amplitudes()['1'], label='2 Fibre')
plt.title("Thick Bar, 1 Hole")
plt.legend()
plt.show()

# %%
plt.style.use('seaborn')
plt.scatter([1,2,3],fibres1.amplitudes()['4'], label='1 Fibre')
plt.scatter([1,2,3],fibres2.amplitudes()['4'], label='2 Fibre')
plt.title("Thick Bar, 1 Hole")
plt.legend()
plt.show()

# %%
np.array(fibres2.amplitudes()['1'])/np.array(fibres1.amplitudes()['1'])
# Out:
# array([1.67170034, 2.10117263, 2.21183736])

# %%
np.array(fibres2.amplitudes()['4'])/np.array(fibres1.amplitudes()['4'])
# Out:
# array([1.0123373 , 1.01828883, 0.92300531])

# %% [markdown]
# # Test 2: frequency = 100 Hz

# %% [markdown]
# ## Thick bar,  1 Hole

# %%
fibres1_100 = Attenuation([],"1HoleThick/1 fibre", channels=['1', '4'], maxx='min')
fibres2_100= Attenuation([],"1HoleThick/2 fibres", channels=['1', '4'], maxx='min')

# %%
plt.style.use('seaborn')
plt.scatter([1,2,3],fibres1_100.amplitudes()['1'], label='1 Fibre')
plt.scatter([1,2,3],fibres2_100.amplitudes()['1'], label='2 Fibre')
plt.title("Thick Bar, 1 Hole, CH1", fontsize=14)
plt.legend()
plt.show()

# %% [markdown]
# Ratios of the data

# %%
plt.style.use('seaborn')
plt.scatter([1,2,3],fibres1_100.amplitudes()['4'], label='1 Fibre')
plt.scatter([1,2,3],fibres2_100.amplitudes()['4'], label='2 Fibre')
plt.title("Thick Bar, 1 Hole, CH1", fontsize=14)
plt.legend()
plt.show()

# %%
np.array(fibres2_100.amplitudes()['1'])/np.array(fibres1_100.amplitudes()['1'])
# Out:
# array([1.38069792, 1.51259529, 1.4750368 ])

# %% [markdown]
# ## Thick bar, 2 holes

# %%
fibres1_100_2 = Attenuation([],"2HoleThick/1 fibre", channels=['1', '4'], maxx='min')
fibres2_100_2= Attenuation([],"2HoleThick/2 fibres", channels=['1', '4'], maxx='min')

# %%
plt.style.use('seaborn')
plt.scatter([1,2,3],fibres1_100_2.amplitudes()['1'], label='1 Fibre')
plt.scatter([1,2,3],fibres2_100_2.amplitudes()['1'], label='2 Fibre')
plt.title("Thick Bar, 2 Holes, CH1", fontsize=14)
plt.legend()
plt.show()

# %%
plt.style.use('seaborn')
plt.scatter([1,2,3],fibres1_100_2.amplitudes()['4'], label='1 Fibre')
plt.scatter([1,2,3],fibres2_100_2.amplitudes()['4'], label='2 Fibre')
plt.title("Thick Bar, 2 Holes, CH4", fontsize=14)
plt.legend()
plt.show()

# %%
np.array(fibres2_100_2.amplitudes()['1'])/np.array(fibres1_100_2.amplitudes()['1'])
# Out:
# array([1.71767529, 1.59270582, 1.5883408 ])

# %% [markdown]
# # Thin bar two holes

# %%
fibres1_100_3 = Attenuation([],"2HoleThin/1 fibre", channels=['1', '4'], maxx='min')
fibres2_100_3 = Attenuation([],"2HoleThin/2 fibres", channels=['1', '4'], maxx='min')

# %%
plt.style.use('seaborn')
plt.scatter([1,2,3],fibres1_100_3.amplitudes()['1'], label='1 Fibre')
plt.scatter([1,2,3],fibres2_100_3.amplitudes()['1'], label='2 Fibre')
plt.title("Thin Bar, 2 Holes, CH1", fontsize=14)
plt.legend()
plt.show()

# %%
plt.style.use('seaborn')
plt.scatter([1,2,3],fibres1_100_3.amplitudes()['4'], label='1 Fibre')
plt.scatter([1,2,3],fibres2_100_3.amplitudes()['4'], label='2 Fibre')
plt.title("Thin Bar, 2 Holes, CH4", fontsize=14)
plt.legend()
plt.show()

# %%
np.array(fibres2_100_3.amplitudes()['1'])/np.array(fibres1_100_3.amplitudes()['1'])
# Out:
# array([1.38894687, 1.42049346, 1.32441639])
