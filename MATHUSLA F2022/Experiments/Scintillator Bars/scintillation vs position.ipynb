# %% [markdown]
# Here we investigate the constantness  of moving the laser pulser on different position of the scintillator bar. We do this because we're interested in seeing how much of the light yield is from scintillation vs from the fibre carrying the light.
#
# In this setup, the fibre is on the leftmost poisition that we investigate.

# %%
import sys        
sys.path.append('/Users/lanabozanic/MATHUSLA/MATHUSLA F2022') # Change this to the dir where mathusladataprocessing.py is.     

from mathusladataprocessing import *

# %% [markdown]
# # Notch 1

# %%
notch1 = Attenuation([],"Scintillator test/notch 1", channels=['1', '4'], maxx='min')

# %%
plt.style.use('seaborn')
plt.scatter([1,2,3],notch1.amplitudes()['1'], label='1 Fibre')
plt.title("Notch 1, Left, Middle, Right, channel 1")
plt.legend()
plt.show()

# %%
plt.style.use('seaborn')
plt.scatter([1,2,3],notch1.amplitudes()['4'], label='1 Fibre')
plt.title("Notch 1, Left, Middle, Right, channel 4")
plt.legend()
plt.show()

# %% [markdown]
# ## stem plot of deviation

# %%
coupling_eff(notch1.amplitudes())

# %% [markdown]
# # notch 2

# %%
notch2 = Attenuation([],"Scintillator test/notch 2", channels=['1', '4'], maxx='min')

# %%
plt.style.use('seaborn')
plt.scatter([1,2,3],notch2.amplitudes()['1'], label='1 Fibre')
plt.title("Notch 1, Left, Middle, Right, channel 1")
plt.legend()
plt.show()

# %%
plt.style.use('seaborn')
plt.scatter([1,2,3],notch2.amplitudes()['4'], label='1 Fibre')
plt.title("Notch 1, Left, Middle, Right, channel 1")
plt.legend()
plt.show()

# %%
coupling_eff(notch2.amplitudes())
